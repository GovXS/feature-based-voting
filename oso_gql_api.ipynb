# %%
import requests
import pandas as pd

# GraphQL API endpoint
API_URL = "https://www.opensource.observer/api/v1/graphql"

# Define the GraphQL query
QUERY = """
query GetMetrics {
  oso_onchainMetricsByProjectV1(limit: 10) {
    gasFeesSum
    gasFeesSum6Months
  }
  oso_usersV1(limit: 10) {
    displayName
  }
}
"""

# Function to fetch data
def fetch_metrics():
    response = requests.post(API_URL, json={"query": QUERY})
    
    if response.status_code == 200:
        data = response.json()
        print("Fetched Data:", data)
        return data
    else:
        print(f"Error {response.status_code}: {response.text}")
        return None

# Execute
data = fetch_metrics()
# Out:
# Fetched Data: {'data': {'oso_onchainMetricsByProjectV1': [{'gasFeesSum': 0.14128102, 'gasFeesSum6Months': 0.0001776258}, {'gasFeesSum': 247.51767, 'gasFeesSum6Months': 43.97236}, {'gasFeesSum': 7.048957, 'gasFeesSum6Months': 1.5529475}, {'gasFeesSum': 10.015348, 'gasFeesSum6Months': 1.8793068}, {'gasFeesSum': 0.2745651, 'gasFeesSum6Months': 0.035528444}, {'gasFeesSum': 0.27559406, 'gasFeesSum6Months': 0.18245688}, {'gasFeesSum': 0.30376732, 'gasFeesSum6Months': 0.033950996}, {'gasFeesSum': 3.785491, 'gasFeesSum6Months': 0.12405247}, {'gasFeesSum': 0.0016287104, 'gasFeesSum6Months': 0.00018553965}, {'gasFeesSum': 0.18124032, 'gasFeesSum6Months': 0.032615613}], 'oso_usersV1': [{'displayName': 'Sushil Murmu'}, {'displayName': 'kkwwol'}, {'displayName': 'Navid Ahmad'}, {'displayName': 'Hello'}, {'displayName': 'Tofu'}, {'displayName': 'AbdulR'}, {'displayName': 'Joe Yang'}, {'displayName': 'Irfan husain'}, {'displayName': 'Ahizu Tochukwu Joshua'}, {'displayName': 'Phong Phạm'}]}}

# %%
data
# Out:
# {'data': {'oso_onchainMetricsByProjectV1': [{'gasFeesSum': 0.14128102,
#     'gasFeesSum6Months': 0.0001776258},
#    {'gasFeesSum': 247.51767, 'gasFeesSum6Months': 43.97236},
#    {'gasFeesSum': 7.048957, 'gasFeesSum6Months': 1.5529475},
#    {'gasFeesSum': 10.015348, 'gasFeesSum6Months': 1.8793068},
#    {'gasFeesSum': 0.2745651, 'gasFeesSum6Months': 0.035528444},
#    {'gasFeesSum': 0.27559406, 'gasFeesSum6Months': 0.18245688},
#    {'gasFeesSum': 0.30376732, 'gasFeesSum6Months': 0.033950996},
#    {'gasFeesSum': 3.785491, 'gasFeesSum6Months': 0.12405247},
#    {'gasFeesSum': 0.0016287104, 'gasFeesSum6Months': 0.00018553965},
#    {'gasFeesSum': 0.18124032, 'gasFeesSum6Months': 0.032615613}],
#   'oso_usersV1': [{'displayName': 'Sushil Murmu'},
#    {'displayName': 'kkwwol'},
#    {'displayName': 'Navid Ahmad'},
#    {'displayName': 'Hello'},
#    {'displayName': 'Tofu'},
#    {'displayName': 'AbdulR'},
#    {'displayName': 'Joe Yang'},
#    {'displayName': 'Irfan husain'},
#    {'displayName': 'Ahizu Tochukwu Joshua'},
#    {'displayName': 'Phong Phạm'}]}}

# %%
# Fetch data
if data:
    # Convert Onchain Metrics to DataFrame
    df_onchain = pd.DataFrame(data["data"]["oso_onchainMetricsByProjectV1"])
    df_onchain["log_gasFeesSum"] = df_onchain["gasFeesSum"].apply(lambda x: math.log(x) if x > 0 else np.nan)

    # Convert Users Data to DataFrame
    df_users = pd.DataFrame(data["data"]["oso_usersV1"])

# %%
df_onchain
# Out:
#    gasFeesSum  gasFeesSum6Months  log_gasFeesSum
# 0    0.141281           0.000178       -1.957004
# 1  247.517670          43.972360        5.511482
# 2    7.048957           1.552947        1.952880
# 3   10.015348           1.879307        2.304119
# 4    0.274565           0.035528       -1.292567
# 5    0.275594           0.182457       -1.288826
# 6    0.303767           0.033951       -1.191493
# 7    3.785491           0.124052        1.331176
# 8    0.001629           0.000186       -6.419967
# 9    0.181240           0.032616       -1.707931

# %%
df_users.head(10)
# Out:
#              displayName
# 0           Sushil Murmu
# 1                 kkwwol
# 2            Navid Ahmad
# 3                  Hello
# 4                   Tofu
# 5                 AbdulR
# 6               Joe Yang
# 7           Irfan husain
# 8  Ahizu Tochukwu Joshua
# 9             Phong Phạm

# %%
import requests
import math

# GraphQL API endpoint
API_URL = "https://www.opensource.observer/api/v1/graphql"

# Define the GraphQL query
QUERY = """
query GetMetrics {
  oso_onchainMetricsByProjectV1(limit: 10) {
    projectId
    projectName
    gasFeesSum
  }
  oso_timeseriesMetricsByProjectV0(limit: 10, order_by: {sampleDate: Desc}) {
    projectId
    metricId
    amount
    sampleDate
  }
  
}
"""

# Function to fetch data
def fetch_metrics():
    response = requests.post(API_URL, json={"query": QUERY})

    if response.status_code == 200:
        data = response.json()
        
        # Process and print metrics
        metrics = data.get("data", {})

        # Extract Gas Fees
        gas_fees_data = metrics.get("oso_onchainMetricsByProjectV1", [])
        for project in gas_fees_data:
            gas_fees = project.get("gasFeesSum", 0)
            
            print(f"Project: {project['projectName']}")
            print(f"  Gas Fees: {gas_fees}")

        # Extract Trusted Recurring Users (Estimate)
        time_series_data = metrics.get("oso_timeseriesMetricsByProjectV0", [])
        recurring_users = [d for d in time_series_data if "recurring_users" in d["metricId"]]
        monthly_active_users = [d for d in time_series_data if "monthly_active_users" in d["metricId"]]

        print(f"Trusted Monthly Active Users (Estimate): {len(monthly_active_users)}")

    else:
        print(f"Error {response.status_code}: {response.text}")
        return None

# Execute
fetch_metrics()
# Out:
# Project: 2fai
#   Gas Fees: 0.1412843
#   Log Gas Fees: -1.9569811065760632
#
# Project: aave
#   Gas Fees: 252.31226
#   Log Gas Fees: 5.53066744741132
#
# Project: aave
#   Gas Fees: 10.13655
#   Log Gas Fees: 2.316147703583013
#
# Project: aave
#   Gas Fees: 7.3798532
#   Log Gas Fees: 1.9987537468156247
#
# Project: aura
#   Gas Fees: 0.30390868
#   Log Gas Fees: -1.191028017440294
#
# Project: aura
#   Gas Fees: 0.28466326
#   Log Gas Fees: -1.2564483411463994
#
# Project: aura
#   Gas Fees: 0.27648163
#   Log Gas Fees: -1.2856108978398435
#
# Project: aura
#   Gas Fees: 3.7939568
#   Log Gas Fees: 1.3334094850484186
#
# Project: gysr
#   Gas Fees: 0.0016297625
#   Log Gas Fees: -6.419320980301019
#
# Project: lido
#   Gas Fees: 14.542899
#   Log Gas Fees: 2.6771028332495015
#
# Trusted Users Onboarded (Estimate): 0
# Trusted Recurring Users (Estimate): 0
# Trusted Monthly Active Users (Estimate): 0

# %%
import requests

# GraphQL API endpoint
API_URL = "https://www.opensource.observer/api/v1/graphql"

# Define the GraphQL query
QUERY = """
query GetMetrics {
  oso_onchainMetricsByProjectV1(limit: 10) {
    projectId
    projectName
    gasFeesSum
  }
  oso_timeseriesMetricsByProjectV0(limit: 10, order_by: {sampleDate: Desc}) {
    projectId
    metricId
    amount
    sampleDate
  }
}
"""

# Function to fetch data
def fetch_metrics():
    response = requests.post(API_URL, json={"query": QUERY})
    
    # Check if response is successful
    if response.status_code == 200:
        data = response.json()
        return data
    else:
        print("Error fetching data:", response.status_code, response.text)
        return None

# Fetch the data
metrics_data = fetch_metrics()

# Print the response data
if metrics_data:
    print("Onchain Metrics By Project:")
    for metric in metrics_data["data"]["oso_onchainMetricsByProjectV1"]:
        print(f"Project ID: {metric['projectId']}, Project Name: {metric['projectName']}, Gas Fees Sum: {metric['gasFeesSum']}")

    print("\nTime Series Metrics By Project:")
    for timeseries in metrics_data["data"]["oso_timeseriesMetricsByProjectV0"]:
        print(f"Project ID: {timeseries['projectId']}, Metric ID: {timeseries['metricId']}, Amount: {timeseries['amount']}, Sample Date: {timeseries['sampleDate']}")
# Out:
# Onchain Metrics By Project:
# Project ID: 5EdcQrpl5M-cgDJHqFJHpe80Fw-UGEwAo9yiquiE478=, Project Name: 2fai, Gas Fees Sum: 0.1412843
# Project ID: XyKL4912vsx41aNjTJDLDexSgi4_BcPkilZ8twJlqxI=, Project Name: aave, Gas Fees Sum: 252.31226
# Project ID: XyKL4912vsx41aNjTJDLDexSgi4_BcPkilZ8twJlqxI=, Project Name: aave, Gas Fees Sum: 10.13655
# Project ID: XyKL4912vsx41aNjTJDLDexSgi4_BcPkilZ8twJlqxI=, Project Name: aave, Gas Fees Sum: 7.3798532
# Project ID: 11awWpg5oXXnNqdmx79GbUOXhE5puhu9dQYnKb_4aoA=, Project Name: aura, Gas Fees Sum: 0.30390868
# Project ID: 11awWpg5oXXnNqdmx79GbUOXhE5puhu9dQYnKb_4aoA=, Project Name: aura, Gas Fees Sum: 0.28466326
# Project ID: 11awWpg5oXXnNqdmx79GbUOXhE5puhu9dQYnKb_4aoA=, Project Name: aura, Gas Fees Sum: 0.27648163
# Project ID: 11awWpg5oXXnNqdmx79GbUOXhE5puhu9dQYnKb_4aoA=, Project Name: aura, Gas Fees Sum: 3.7939568
# Project ID: drRW7Y2sqeeFEMq9PpR8lIaAINrlcXKH09EJ4WsbL8E=, Project Name: gysr, Gas Fees Sum: 0.0016297625
# Project ID: m3u9RgYlYchemnTKZDZSZV9xLGReVz_KGG5sV0tIrUE=, Project Name: lido, Gas Fees Sum: 14.542899
#
# Time Series Metrics By Project:
# Project ID: 8RsppqhF6-tHDEnVATmtwf_fUMeOg6EsIn92GIR7NkI=, Metric ID: Zi2ZgvlL3ksTcYSgQ6yvav83RLfwCwtTeCd0rFpV3bQ=, Amount: 3, Sample Date: 2025-01-16
# Project ID: KEEBnsnsYBPgW5YvPDLHWm08v6YnPGXVnSJIxblxT6M=, Metric ID: nHF+SAURcTdQ8H/JQU8H8awZxAs5uhHdydUc7Q4uaE4=, Amount: 5, Sample Date: 2025-01-16
# Project ID: dTOJVgcd44Xv1mkV949Tyyyx_WO6HOsCNSFEP-MP3HU=, Metric ID: 7PwXon1uEY21Z8vW7uTTrxMVc68kRUzs+IragtA2Mao=, Amount: 2, Sample Date: 2025-01-16
# Project ID: pKrsAdCqXLx_igOIoEF994iMr63rG_l4_hKjYGAVXGs=, Metric ID: nHF+SAURcTdQ8H/JQU8H8awZxAs5uhHdydUc7Q4uaE4=, Amount: 2, Sample Date: 2025-01-16
# Project ID: XzqpoWqrRksMe2M7TFXg7BxVchB2nmJGoE78teTh9-U=, Metric ID: /3v26jfsOswJmGRIAQiiwVjYPqYTwQDlD2dQMR0h3yw=, Amount: 3, Sample Date: 2025-01-16
# Project ID: c0SgGbJHGC3NvJcp97MKKBxIGtJIi3pIWz2l2WxuWaA=, Metric ID: nHF+SAURcTdQ8H/JQU8H8awZxAs5uhHdydUc7Q4uaE4=, Amount: 6, Sample Date: 2025-01-16
# Project ID: gOHqE6igA5QEY-67stuWJsMPDWp2gOihpya9XaKeONk=, Metric ID: 7PwXon1uEY21Z8vW7uTTrxMVc68kRUzs+IragtA2Mao=, Amount: 4, Sample Date: 2025-01-16
# Project ID: HC4mNpclbKWrBgbOYtYL0hyVI9fXcuCuEoj5wiqNSo8=, Metric ID: nHF+SAURcTdQ8H/JQU8H8awZxAs5uhHdydUc7Q4uaE4=, Amount: 25, Sample Date: 2025-01-16
# Project ID: LOZXloZfVxGx7h5Na3R-5RcR86-mMDDJuKiE4q_hJOY=, Metric ID: nHF+SAURcTdQ8H/JQU8H8awZxAs5uhHdydUc7Q4uaE4=, Amount: 3, Sample Date: 2025-01-16
# Project ID: MNydiyNydgegnTkpeQH-W3H3O9inqaTo2-EP31yOONM=, Metric ID: /3v26jfsOswJmGRIAQiiwVjYPqYTwQDlD2dQMR0h3yw=, Amount: 11, Sample Date: 2025-01-16

# %%
import requests

API_URL = "https://www.opensource.observer/api/v1/graphql"


QUERY_PROJECTS_METRICS = """
query GetProjectsAndMetrics {
  oso_projectsV1(limit: 100) {
    projectId
    projectName
    projectNamespace
    projectSource
  }
  oso_metricsV0(limit: 200) {
    metricId
    metricName
    metricNamespace
    metricSource
    description
  }
}
"""

def fetch_data(query):
    response = requests.post(API_URL, json={"query": query})
    if response.status_code == 200:
        return response.json()
    else:
        print("Error:", response.status_code, response.text)
        return None

# Fetch projects and metrics
data = fetch_data(QUERY_PROJECTS_METRICS)

if data:
    projects = data["data"]["oso_projectsV1"]
    metrics = data["data"]["oso_metricsV0"]

    print("\nProjects:")
    for index, project in enumerate(projects, start=0):
        print(f"{index}. ID: {project['projectId']}, Name: {project['projectName']}")

    print("\nMetrics:")
    for index, metric in enumerate(metrics, start=0):
        print(f"{index}. ID: {metric['metricId']}, Name: {metric['metricName']}")
# Out:
# Projects:
# 0. ID: FZyANfBAocvep2LvoyukpWDW7ZmzfgXn35C0zqVZtg4=, Name: zondax
# 1. ID: LfPZpLGWyicwCvyWS-57HEF5XMEyKBtkGMMxXS7d2Wc=, Name: 0xlighthouse
# 2. ID: gXd_VZ-uijSkl5J8Qo2WKJ84Y15FZ801GRvc6oI818E=, Name: zerodao-finance
# 3. ID: ro7Y2_DxRXKXZx-jbI3pv9IkOHSNNSdzKH6hAZ74Op0=, Name: relinkd
# 4. ID: og7qMTSu2aRushlAUKWD22UhCKJY_Hcs0FcFQpjoR3U=, Name: ethhub-io
# 5. ID: rLw1b0UsMNE_FDVwCb2yFFQg0He5hCSSmizhQI5wo2g=, Name: mystcl
# 6. ID: cLZx_e_EZ-UuWqfOXvqTyUZfecyfWGmbQnA2lRMKrR8=, Name: unitapapp
# 7. ID: 7G1BqDhcgOt5B9WfET8aQu9so0H7Z7d2kIya4cifRJ4=, Name: lxdao-official
# 8. ID: TfsX_8fdK4RBog5Kp0ZeVHVlhV_CMS_Gh8Uu09JeEq8=, Name: openbuildxyz
# 9. ID: hlK3dluJKJjDDYDOGDrvLbZTAC2q6RMIBTVnP3-o1LY=, Name: jacobhomanicsorganization
# 10. ID: FauI5kYd6htIGa3oGEMrtDDHwGaNuhz8GtWWcNtTJjU=, Name: omnisea
# 11. ID: YcaW6oSxCoxp_sKzaAq1HoWEvSzemfbEGHQduAb_hJY=, Name: verifier-alliance
# 12. ID: ZgDMWEQQ1eHPBxAhmFPcBE26wAxBI18-vrGeCWL7rv8=, Name: nicetrade
# 13. ID: FByEBpOMDxHXBRPtEc_b8GxmUAeuVyehxdqIUp47SWI=, Name: saddle
# 14. ID: tQVoSoBPL9kHB8XHwNH5S5iCMwj-uwA-R7Qnc-8vYV8=, Name: solcapture
# 15. ID: 1-j70TCK-TJt9tIZmZLK1-O9GOUjWLSsy5IEs4UCS9I=, Name: sorare
# 16. ID: zclrWgfVwQhMpDcbsgrfrORaXm7PQ5M6fddylOoVhQk=, Name: solpad-finance
# 17. ID: 1dFmyCclO7JiD2FhK2rk5OsskebW9UObEsDJT8z3Mro=, Name: conventional-changelog
# 18. ID: ohrftDmbxqVoKeMEAll9uPe9pTx7DUuSGcuhE-92UHs=, Name: 0xpolygon
# 19. ID: 6U8ti2ENbo7FSaY3CvOtJrIuAlaGK_Tp4lvqst4NgvQ=, Name: zkvalidator
# 20. ID: 9lSGgGzAQzLYKMhVAJS6_7z5OuYxXMttt6AXot_rPkw=, Name: getprotocol
# 21. ID: BE84NbNihxKpsmpQP8neKzg5LxmML_YBP_Uk1Ylb0pU=, Name: personachain
# 22. ID: cP-6eSSLbK9NARftgpxHm6NAqy-4luKR4KT1aHNHJJU=, Name: wasm-cairo-cryptonerdcn
# 23. ID: _OOgeXYp4SV0zvf7FYdtijqoRhQAEHkhhDnRzfyEs6o=, Name: celo-tracker
# 24. ID: kh9ApEUsu11JsDGySiyxXkpb3ExZG1Qh12Bo-uHsreg=, Name: magiclabs
# 25. ID: LUYcIiTAz9UMY-Mi-ZeuxHOabGBRanS9zYaMUNlP8P8=, Name: dao-driven
# 26. ID: Mv3E4HSrnfJvKzvuuTpUwELLl0H6IZGvpJJJjtL5l_c=, Name: monas-project
# 27. ID: 9mnn_RPL5QDVB9RhsltpilT4D5wUmWbAu5EtOTDIu5A=, Name: nsure-tech
# 28. ID: OKrxpds0Lpt711SaFeXQj1VI0VYRgN2vp5FRbOeeYHw=, Name: form-data
# 29. ID: zOP9XrvWh_SyLS-9xECSnNLZEdlHSD02IQaoc78vPs4=, Name: ludex-labs
# 30. ID: Bx8xQwbLPf9IA3gxd3IXx2gwme6QJkLI6YayDIFAsIo=, Name: zkex
# 31. ID: LTJi4h2STl9JYZe9DI6iJbN3BDy72MvhFxOGeHEhLvI=, Name: kumo-earth
# 32. ID: -AMf3rSwuyx0_QcgNc2zEWVaMgIntSbx11wHZT1i2C8=, Name: salva-terra-foundation
# 33. ID: TExQf0p4FgeEqtxvdg5qe3p4OLEDDVtzEuum7EPILoo=, Name: deepeth
# 34. ID: iI00jc7_mXJUne7f_HSd_lKUtD8dAYlF0uiAj2l9sHo=, Name: metasol
# 35. ID: 9Zwie5uRxv7clfDd9qFmkHg2ypAYm4fKhmaruTc3Ny8=, Name: stallionstake
# 36. ID: ys-kH8XRyY2cYi3OOwbba84rhyXxzvA_8TFNrC2MG1A=, Name: getwalletx
# 37. ID: rrj9p5yHl_-zJDKkFfQS4mEzFV9pTsc-dUhJWGL1E4c=, Name: buildonhybrid
# 38. ID: 7X6_WYF_o4I3l3NkEVJqz1qVR-qnUhcBvgp9ZuLAhLA=, Name: ipor-labs
# 39. ID: Iyej_iqvPUU2iwsKT6sYOEPMCK41tM8aGbsVFth3ES0=, Name: erigontech
# 40. ID: UT8S5mjydoRt7aW8sepUQv_997x7m-QV6R8zmatdJ7s=, Name: hellobloom
# 41. ID: tl-3BhydiL0d3eyxCvUBDYQ4eKCISSmPtmF4cFodz74=, Name: hiro-finance
# 42. ID: TipP7HiCu1IWdOS_MqvQfgiayP77-_h7vHSiQs89XgY=, Name: toadsadventuresincryptosecurityland
# 43. ID: 1yq2RdYGy572viFw-LbOVWoHrf_V1x96QmECxjAbbFM=, Name: quick-intel
# 44. ID: nd4Xx8I_MqqSlhPpDeAfWUW6yyDQ8zge40flP0DLd2Q=, Name: the-arena-fun
# 45. ID: Y0465tTZUG_gOIddYwe9gsAB7WMTsZTBZj6mFbIp26Y=, Name: aphidbyte
# 46. ID: zn21BpqMkSBnyTLosH5GjlsnKoJgvPTQ2YtNGQGkH_8=, Name: b-rder-ess-dev-hub
# 47. ID: 3uA_LDx3oU5SxGpo3wFaGAWcrZpOusFsUtuqacDB1Ts=, Name: decenterapps
# 48. ID: LVTZCQhqf5FN2ODfWw48cPit1d4-eLAR8NhW32y5fyU=, Name: crynux-ai
# 49. ID: RNlAz2hQINnF9dXYV_bMQOBOfp9OHW3ZT5T4Vj2k3hA=, Name: modular-crypto
# 50. ID: CVJgJLcuYCIjTAdsZWRspcUCzbTzlI5jB4NqpOM1Cqk=, Name: nestedfi
# 51. ID: UYEDUoMF7MRmDAlVFTaadZ2vFXpaS8bRk2ebXU9bXJY=, Name: yusufpapurcu
# 52. ID: 7C0Y9pKahyiVemmphEKJDgA_UcfnUU0lrrlRpVU2VH4=, Name: jellycuts
# 53. ID: vh7miJ5IwryZq8vzOFdo1eKV6Btfdvgcv89GD0wZHjI=, Name: locus-finance
# 54. ID: hCQHACRqCNuTV-StzlkGePPofAbafTPoXhAAhSicS1Q=, Name: zksync-sdk
# 55. ID: aFc-gWLDg6FCWzFaLWUOHo0RbCtb0wVTm7f6TtESMDg=, Name: aramidfinance
# 56. ID: tlBRDj9Fi404dwNJw-MmgZI2rMuT7JZ7jgKz0iXSKwo=, Name: go-sourcemap
# 57. ID: le-5t1cSer7w1-g29ClDnGHeAHgYvHdEcAPJK5J2dK8=, Name: sonarwatch
# 58. ID: cYrTIa16mnqsmyE6j8vfMj3mtQ-Ud7ILVKdxu-53FLU=, Name: reaudito-org
# 59. ID: YbnmPZvyfcSGQbcb3MMfXAwi84_VvVfNrgQpe8Gk3Kw=, Name: ellipsis-labs
# 60. ID: -7MOtW-S9qo_TjTQioXWkT9NMxDYKe7Z7dCKeVfep-w=, Name: savour-labs
# 61. ID: Q6Y-F_I1OFWLtjrm1771hdzBFTFiN43si9zlWmaiEao=, Name: coco-verse
# 62. ID: k67j51vEmP489LjJr987aZFZVGelWPPQFlsmTuIIdSo=, Name: marinade-finance
# 63. ID: dRHsMUMq4tXxWC3ZShTDj8g-cw0dyEsb5Z85LILah4k=, Name: cryptocuriouspr
# 64. ID: noq49IlnVPxp1rasoYH39AAyV6IsJGl9kmpuUFYjX3Y=, Name: plants-and-pillars
# 65. ID: jY6LcqPlEerC70D-drUIb2kIVQnj474b9_JGx3Yvu-Q=, Name: topianetwork
# 66. ID: 6RbJ7fhcEoin39N2pN8WMvaRQe3TVP_JaohQ7nvojCs=, Name: daimo-eth
# 67. ID: dF4keWtWXOAGkPWf8YIC0rwnhcfV7uJvnc_g6fkKWPM=, Name: filosofiacodigo
# 68. ID: JXJm3pOiLPH5J-gYseyAk1ps4dL7nCXtH0gUHIX2wnY=, Name: ripae
# 69. ID: yoTEFjM41Rn4qnyOU9KIoMsA7TiOHfpfn7iQR3FtZW8=, Name: ensofinance
# 70. ID: 2aoT9cLEejbXS4mdKHUogGKcKGzN-lbEW_pProvv5F4=, Name: linea-swap
# 71. ID: -HFU2CHl9yGvaWeHTAZZjEkoGFFA-mFJdpn8qhohT0o=, Name: dataunion-app
# 72. ID: jK5OGdAax2vHemEg9dCwE8cho9uaREaexXzF43CVkws=, Name: d8-x
# 73. ID: GEYfldHxG_3f3nMBETP1szoTdPRn88xY__LCPPn2CDQ=, Name: crunchdao
# 74. ID: a13b7K1ot-Tif9VlhyzAhqU2DAkX_h5fJ2LQJVPKJEY=, Name: eth-limo
# 75. ID: jCJmw1lR3kgWutpBe04sLfsOL50uszV7h3KS-LHXe_o=, Name: reach-sh
# 76. ID: ZfA0PO9GTyc3GFQhSoWRsrw55maNFjaoDQmC3vGuS6w=, Name: onlydustxyz
# 77. ID: jI_PQ7btn6ICgTGa641OB0Mfq1NNv5uackPYpzV1Pe0=, Name: defi-africa-network
# 78. ID: 7v8BJjk2KiuAkzVpotkU_r31cgu9Jui8fL3hnMZWvyA=, Name: izumi-finance
# 79. ID: Yy453z3uprDnWGVFCkIptRzbE9s1arbMglH6zgTes3s=, Name: owlto-finance
# 80. ID: xRKH3DnDNWP4cVfWmgiJVaAD1iu6p3lbzu7nd22coH8=, Name: copin-protocol
# 81. ID: LYjorXBAT3ups7hO6SJ_Uy7fft9PqTeD3Nq2m2El7uM=, Name: buidlguidl
# 82. ID: NECof-fua5rp-JQa4gpczoqlhFifv3j_NBwb2CtfMy8=, Name: discoverselab
# 83. ID: XP6-tWcpnt_qvrYK_yiEu7uh1SPyU3xKC4Pls9InBck=, Name: renzo-protocol
# 84. ID: YYvuMg0WiauShqpPUtoumkjHGcil-FI8bcKLc-Fy9xU=, Name: chaincraftgames
# 85. ID: W1Y0YdIHScazGk_CfHebBjnKTvksjvzTHI2Spt8JrBM=, Name: goodentry-io
# 86. ID: Nrq_0147qHxF98e0W_bipHKpmX84BOA5S1Tcp7Xt5IA=, Name: daomocles-heeju-k
# 87. ID: u2HjXdaZiPyiao5MhpQiquPApkwiE-Lz_rDZfwKHwLA=, Name: halodao
# 88. ID: l4XzDqyfoZO4qM6T8gxojIDtYXorh2IbS6cDtslkoi0=, Name: cyclos-io
# 89. ID: JvnCf3r-aLE2wVoGRRboetsEbBIQsSZqAahtKPiiVvI=, Name: hexpay-day
# 90. ID: i4NwTkQuAbGqqWjxzHT-Ndb7IRdaIeFUuI9Uo9Q-els=, Name: gigawatt-core
# 91. ID: L1qK5iD-7M2W_lmLqYxryWw8mRwIfZq9T8auCjfOpfw=, Name: matrixdock-stbt
# 92. ID: 2BcOxj78tTofUoCYONuGekKL6veq9UZ74o4d1wfNRZY=, Name: yam-finance
# 93. ID: VUyMaCu3aGwxyUPcTAvfRCa2OfqgB--gNlPfLSCkxGM=, Name: gracie-platform
# 94. ID: IzOukUSVxEb3CF-tcyC0ZPA7_Kbk_DOgI7s4mgyHVIo=, Name: lightprotocol
# 95. ID: eNA5sb_fN6GeZ66jSYvmiJwDS54PbtNY-wog4XBd28M=, Name: axis-fi
# 96. ID: l5hdHDPXN2q4TBxeo-Du1DVpetlAjzHraQXxiGPSTYI=, Name: solstar-tech
# 97. ID: Cu-TNsuk6k6gibp7HLqWNOSnNBUBjnS9z8Hg5TKAqes=, Name: byrnstack
# 98. ID: B3a79bw7YaBPVVll1LKrx4MYHRMJONm8AZu-znlzLw8=, Name: vweevers
# 99. ID: rzusenidRMBQYbClXSdzECk8Hdz1wZzhcTwNeF_9nyw=, Name: bitkeepcom
#
# Metrics:
# 0. ID: jZ7eA/mj6eM2klxuIvBf+7k679/d+t3Z+rwPIr297lc=, Name: GITHUB_avg_prs_time_to_merge_over_180_day_window
# 1. ID: 0uIhUzlQIYivDNMb9bYe5vjU4yOSh2IsB4Qdr8gnBXw=, Name: BASE_active_addresses_rolling_over_30_day_window
# 2. ID: /+ZKYLSQUOV44ubj9+R4Y7ighiIiVqRW3pzDrz/OGsM=, Name: BASE_TRANSACTION_COUNT
# 3. ID: hcRAQoKE3oMqgmWGy2C5Iuhf11fjEWWooyOtJiVq1zY=, Name: PGN_active_contracts_over_all_time
# 4. ID: vY0Fv2slchduNVJ5ufKOtPNno5n0kFvuaEFxuc7n878=, Name: GITHUB_comments_daily
# 5. ID: XQx1UKWibW2XMAFiAlWG4eqmXcb5PCAVqDRPa6hzC6Y=, Name: DEPS_DEV_dependencies_over_180_day_window
# 6. ID: 99aVAB6roJjNzlHCzA4byZZlMiI5YJCVW5TtVOGh0Ro=, Name: ARBITRUM_ONE_active_contracts_monthly
# 7. ID: lC6p7VPRSMYsSiGycBzn831YFTKq32eQbqU2LzFqAAc=, Name: METAL_active_addresses_aggregation_monthly
# 8. ID: VJGfY6jOsrP5ay9SKd3CD2BNLp4TCqzfPVyHqFRt9e0=, Name: FRAX_TRANSACTION_COUNT
# 9. ID: AXNGMgqVRFZ5DzqJwzXLG1T5HO/brpPUipnBaz8Ev5E=, Name: GITHUB_commits_weekly
# 10. ID: nj36RoWkD0rew/dJbX6tKEeZh8TTVU4dXJRmcFf0GLM=, Name: MODE_transactions_over_90_day_window
# 11. ID: voiz5YtKLq5ckHyo07QLGdI3ddFiFrD+LbaScRed2vk=, Name: GITHUB_full_time_developers_over_30_day_window
# 12. ID: rjKymx09k28lnSZ3m8y2Y8Oc01yFiUbgVFxdT2DaAcI=, Name: GITHUB_FORK_COUNT
# 13. ID: uNSQLLE7ifKzrgXnEr87yPux7Q9aJGmJkvf1dRZfvFw=, Name: PGN_TRANSACTION_COUNT
# 14. ID: B6k/76djlWTipz1YLUhk72SYNWVVTZirEKO0fn57F9A=, Name: FRAX_active_addresses_rolling_over_90_day_window
# 15. ID: nK4tvv5bzn1Z/ynm3Tslir7fuxtQCxfzRzJrow6rsR0=, Name: OPEN_COLLECTIVE_funding_received_over_180_day_window
# 16. ID: Bzhn0+eW+asndNlv0Pub54/RldAJ1jkx6SqcXe1VdBo=, Name: GITHUB_releases_weekly
# 17. ID: VYWe0010rYCVSJ/tU7w0/LpzFNzPwFRchjm9xRonNn0=, Name: METAL_active_addresses_rolling_over_30_day_window
# 18. ID: vFN5mEWIASKitB/zHCWowEjOUwibK8NJL1/WbJjDLi4=, Name: METAL_TRANSACTION_COUNT
# 19. ID: /4F0OMwcRLpsgtaCMNwAhls87NuYi5gShe8Jrdt0iIM=, Name: PGN_active_addresses_rolling_over_90_day_window
# 20. ID: Zz92tXhK6b+RiNWdjFNYbcFJrBu7AN4rTMzy3qkEwyk=, Name: PGN_active_addresses_over_all_time
# 21. ID: yqj6JWZyuLBwZYUwDTC3QAmj2fJcuAUNbMxQ8D+nyOo=, Name: GITHUB_active_developers_daily
# 22. ID: CZj6oh9q9iZgTkOq85makmZb/9l2hP/mBgn9PbgfXmw=, Name: ZORA_gas_fees_over_30_day_window
# 23. ID: jd+ZVj/wH3m/D6rDFWkOqRHP+hrbvvJsrqROCz3uAQ4=, Name: PGN_transactions_over_90_day_window
# 24. ID: ZTzeY9UqWNCq4sGGj6WpvxzVcKARSpc4heWBg69SogQ=, Name: GITHUB_change_in_full_time_contributors_over_30_day_window
# 25. ID: qqIOR128CBt3JryYDCEBHiE06KoQh2OvYr8CwpJGEAo=, Name: OPTIMISM_active_contracts_daily
# 26. ID: 2JwncBLkcxiqG8SmzaRa5JHAiS1sBwNWPvtK/lG36/s=, Name: ARBITRUM_ONE_transactions_over_90_day_window
# 27. ID: N9AMF3CVNfSQwqUpOoRmhLyYyGhta6nFJpE/48y4Vgw=, Name: GITHUB_avg_time_to_first_response_over_90_day_window
# 28. ID: Eq4pIKDKSLSt7Hc8nZRAnZMaQggzV3g5IF9BmwSLjcI=, Name: GITHUB_TIME_TO_FIRST_RESPONSE
# 29. ID: 0xy+em6XN6wQKZMqtspcmc49ze3hD4BofTyMG+PU2OE=, Name: GITHUB_commits_daily
# 30. ID: zeFGq6xjNReF6Svz1+m7Kjn424nuD2M30kPt/wjN3zs=, Name: GITHUB_PRS_TIME_TO_MERGE
# 31. ID: xLXo4LxSCIykXygIgXCAME2EOIZ6SA648iLiecnIfMw=, Name: GITHUB_churned_contributors_over_90_day_window
# 32. ID: JmQxvcVG7/HmxyRLKMZXmviVV+sOhg8fV46/fMQnwpg=, Name: FRAX_active_addresses_aggregation_monthly
# 33. ID: ZgiQxVmY0oYw8gWGex6BX5nM4J2bFpF3nRjmgkCn7o4=, Name: FRAX_transactions_over_180_day_window
# 34. ID: NEHiVhiO6+im1EI2lJwWgHMtELAN4WHrNVNOw8pHm7k=, Name: GITHUB_CONTRIBUTOR_COUNT
# 35. ID: hfs4p273MOjhJbXrkuXtKGj/RQhWZUP6nihG6bKdRD8=, Name: GITHUB_active_contributors_over_180_day_window
# 36. ID: alcJCP1SEvIIibTqOR+ykw3SR1Ve+SjkQ/5DvVywB7o=, Name: ZORA_transactions_over_90_day_window
# 37. ID: 7qml4fKzT5FE9AWb+l6ciDQkAYDH5HsfkVwOmH307Tg=, Name: GITHUB_active_developers_over_90_day_window
# 38. ID: ZpcWY8C66fJNdos1LT9r8RFoQSXcUFPkH+Q74ZgojIA=, Name: GITHUB_ISSUES_CLOSED
# 39. ID: phz0I6Ki6FgpKOqUaRgDe0iughBK1kqHMmfEV79XJHY=, Name: BASE_GAS_FEES
# 40. ID: Fkid4Y9N+xCojxH+/CyLS0D1ABLKtyaGV8SZdi5RSDM=, Name: OPTIMISM_active_contracts_weekly
# 41. ID: 9IdGqA2f0vZhpMzCKkEZHdAH2U5KVlI1bCKIIozu8lI=, Name: GITHUB_part_time_developers_over_30_day_window
# 42. ID: ez6ogZLFCOnsuUd8JPt6oBmXc5dOZRVetIFcjAiJ7JM=, Name: ZORA_GAS_FEES
# 43. ID: L3ikEIYHgCkAyLzTmHooYQh5UCoJ67SUNNaBs6eq6Kg=, Name: GITHUB_STAR_COUNT
# 44. ID: 00Aq9+bE+vFk3sxDXVUNO+C2GV0UkwrbzPcKFqXKTaE=, Name: ZORA_active_contracts_weekly
# 45. ID: bnvywdYbu2azFYg9CV4QntbUTqnEQqdssC9G9RH8QhQ=, Name: MODE_active_contracts_daily
# 46. ID: ecwzyi1upe5n6ZtRVqDnbbH984oTRPH0eHEqeQT+aaA=, Name: ARBITRUM_ONE_active_contracts_daily
# 47. ID: 6C+b2mjvxqVmSnKlQTauW8tz6VueOyfFRkr2EMrRTHU=, Name: GITHUB_REPOSITORY_ENGAGEMENT_COUNT
# 48. ID: x3dgf/JlKZv/1aDIvyHkSucCUT54+ZcjpLQ1AswWTAE=, Name: ARBITRUM_ONE_active_addresses_aggregation_monthly
# 49. ID: 8S4VoU+7j8CJ3dmazBWbQQx8ijYi0c/lDXamjUNJI/0=, Name: PGN_gas_fees_over_30_day_window
# 50. ID: nHF+SAURcTdQ8H/JQU8H8awZxAs5uhHdydUc7Q4uaE4=, Name: ARBITRUM_ONE_active_contracts_over_all_time
# 51. ID: C/vtu+eSP6yPfmCxqd4MI9sOdWRaWDWf3O7bWNFfAl8=, Name: FRAX_active_addresses_rolling_over_180_day_window
# 52. ID: rb3SUJyhzeStCJeAlC3U8bCXLl6b2dbtXAMCegSiTDg=, Name: GITHUB_DEVELOPER_ACTIVE_DAYS
# 53. ID: jGjBAPWwZgIIxiP/8mkll3Gi9Qkvv4WOYl4CGm/mdI0=, Name: GITHUB_comment_count_over_all_time
# 54. ID: MHRQextIgNqx2oKPzsLaDr6s/xz6rJ0g3Q1ELNN/QPM=, Name: GITHUB_new_contributors_over_30_day_window
# 55. ID: 0/l2WfTLfGsFtf7uRStQpv75wq/Vahl8zawc8VidqSU=, Name: GITHUB_part_time_contributors_over_90_day_window
# 56. ID: /mBeTkL2hMjcEODGRnToIfc7zjquJq5Aluy7fYJNhEw=, Name: FRAX_gas_fees_over_90_day_window
# 57. ID: 16UaFtskR3v0DLnXnJqsn/BAcWkDCX/1RFpfxiMtON4=, Name: GITHUB_repositories_weekly
# 58. ID: oS8ScRJjXnL2GmAYf3/2EmB975N9k9EyOqxoCZyxK4k=, Name: GITHUB_PRS_OPENED
# 59. ID: pTp/OhlQHn3DRsIUXwqZlbHyw1ZeLaR9PIGbsSe/pjE=, Name: GITHUB_part_time_contributors_over_30_day_window
# 60. ID: /5K1nZsM76h4pTmTf2ns3m88EpdvdTObrX4gkNZUhv4=, Name: GITHUB_repositories_monthly
# 61. ID: uaBTAsxHCI9dNBWhU/STiQpK9KPY6k0JE8nSaGz6+Zc=, Name: ARBITRUM_ONE_active_addresses_rolling_over_30_day_window
# 62. ID: S2mKtDmIF+Yab4DdsVAllvKhKkDK9cN97455SuPcuVw=, Name: FRAX_gas_fees_over_180_day_window
# 63. ID: 0EMSF0WtbO9g6I6nA9Wew8CmFloZ31gsJlaWFxfLz1E=, Name: OPTIMISM_active_addresses_aggregation_monthly
# 64. ID: /5GO6wVD+SXuTTKF1wpzMQ1P0iv2mlTQyZk7Wxmfg6s=, Name: GITHUB_active_contributors_over_30_day_window
# 65. ID: wGANOBUtugc8wFCfTOhZDZtyggT3cobRHhWDJu/A4k0=, Name: GITHUB_contributors_weekly
# 66. ID: j7FEQ7G/ysZGCQDVMolgGA575NBed9nnv7Sos1EBLSc=, Name: MODE_active_addresses_aggregation_daily
# 67. ID: y6IgBOKphmbhtv4Gp1aqOAAvVbR9cvnFqj+ZU1zyxI4=, Name: OPTIMISM_active_addresses_rolling_over_180_day_window
# 68. ID: 1p+a25YZLftr4IpXLtSnv0pzNZHuNxb+hNVMX1HhAnw=, Name: GITHUB_RELEASE_COUNT
# 69. ID: QGtLjCZrtG133rkFTBc1pGZP5j5QolAEtg8m3i3l+kg=, Name: FRAX_active_addresses_over_all_time
# 70. ID: 7PEA33NdLXZ97ichlOnybqpjNAFz84fYFp+Gm7OgGw4=, Name: OPTIMISM_transactions_over_30_day_window
# 71. ID: kX7k8ng2wTgPQcLYMNTGPk5rjWwmo/N4TacaYppMkqc=, Name: METAL_transactions_over_90_day_window
# 72. ID: ibsfvk55m61nSVkKvAw8AEmXlth8/QlM/lpBmK2CNEY=, Name: METAL_active_contracts_over_all_time
# 73. ID: HgUIVwg+PGeZQajBjosa1cxpWj9+k6QJVWdraTatikI=, Name: GITHUB_change_in_active_developers_over_90_day_window_over_90_day_window
# 74. ID: lfHNfMUQ4nRqeSSOyAuIG47TI2xgLFB5zy/LHRv4J8E=, Name: GITHUB_forks_monthly
# 75. ID: tRJ6gO789gRdT6MAswgS6kgtQJIwEYYpA5rVdLCwXQI=, Name: DEPS_DEV_DEPENDENCY_COUNT
# 76. ID: VVpNKg4Y6VHEhNO0SlHydeLuCr42jN4EDaFjO6xO91o=, Name: MODE_active_addresses_rolling_over_180_day_window
# 77. ID: lPCVS4yB6uYBo4DwI62GzFz9otasoNOgAoryagXX5F8=, Name: PGN_gas_fees_over_180_day_window
# 78. ID: fyc2e2cQLXK6JrSRqp3+ffGYDvl7tjMZdJLs0qWBADI=, Name: BASE_active_contracts_weekly
# 79. ID: rqDd5VdGYototVBi/3mINAp5bk5J5addwCqobJe+NaA=, Name: ARBITRUM_ONE_gas_fees_over_90_day_window
# 80. ID: svdIMI4maIJVl7rpGTTBIrP/OlEiavc/vwFskErvdyw=, Name: GITHUB_active_developers_weekly
# 81. ID: 6v/jj5fBkKzJyidi7Yu+SsnbXz5uZTt/ZodiRaopwaY=, Name: FRAX_transactions_over_90_day_window
# 82. ID: 9Gj920NAJWeMrgZL0imQR9WGsoKZJhPAZAsCou1fuk8=, Name: OPTIMISM_transactions_over_180_day_window
# 83. ID: ezfT/VLvs0nZAg9vGCtHQA8Hm7HFV6uGgsqtdOZwGYE=, Name: GITHUB_change_in_part_time_contributors_over_90_day_window
# 84. ID: UqpZGDPF6+cfPqlOVOJ/w7Rp86omiVCwhiPQ9IuTwEA=, Name: ZORA_active_contracts_monthly
# 85. ID: 4z4uM0tIBSGz3Jwlblq0tLtDoc0se4r3FSe+QVqG660=, Name: OPTIMISM_transactions_over_90_day_window
# 86. ID: hnpQ2FkTdJuKnTYS5D3sDIJNm1TTIv8QySLi/yAurvU=, Name: BASE_transactions_over_180_day_window
# 87. ID: o9FNcBf9hVuuy+l/yRcukD9RsE11P7GAfW/b8v43n/g=, Name: GITHUB_avg_time_to_first_response_over_180_day_window
# 88. ID: 7PwXon1uEY21Z8vW7uTTrxMVc68kRUzs+IragtA2Mao=, Name: BASE_active_contracts_over_all_time
# 89. ID: ekthjEH8DEy/h2X//Rvqjx8BFr44S0ik2tmWr3XoVZo=, Name: MODE_active_contracts_monthly
# 90. ID: QP+CQBI48No1UqAJDA8nxWkDPCgva0htwJM6wlcc7q8=, Name: ZORA_active_addresses_rolling_over_180_day_window
# 91. ID: ZQkqXxnsDQVJU27gvtSwULldrZUpIKsJb2r7V62TMBU=, Name: GITHUB_part_time_developers_over_180_day_window
# 92. ID: Zi2ZgvlL3ksTcYSgQ6yvav83RLfwCwtTeCd0rFpV3bQ=, Name: ZORA_active_contracts_over_all_time
# 93. ID: ybrUPmPMm8zvOmcSxrF+FUU6zLNGzAsq3UusUHeBhvc=, Name: GITHUB_change_in_part_time_contributors_over_30_day_window
# 94. ID: 0ISRtWqYorwEeYMqNeC67wK7l41d3DV/45I8IRxtoCo=, Name: GITHUB_part_time_contributors_over_180_day_window
# 95. ID: AtitjO4LFVxuaI5caWkIywUO7XMCQNv20AiWDDmxxyc=, Name: GITHUB_contributors_monthly
# 96. ID: 0XeJFfKdveMFy8TEmD1IHsbhH8P90T/zGMF0U2PzYdg=, Name: MODE_transactions_over_180_day_window
# 97. ID: V/l8MEdIHJOr4LyHRyVsyHmYlLitBd6omu0p9F1aKmY=, Name: GITHUB_change_in_active_developers_over_30_day_window_over_30_day_window
# 98. ID: TlX24EOWdinY/tsIuSaDScI5s2Q3ssFlXexBXSq7AF4=, Name: PGN_active_contracts_monthly
# 99. ID: 0Sw7nT0VHYIbLLr6f+DZIzQeUkrCpncc0vAD8HYv2gM=, Name: BASE_active_contracts_daily
# 100. ID: e89agWQAyWcF9FIm9qERUqYeCfSpZ1LYkqlNjyRGwlc=, Name: MODE_transactions_over_30_day_window
# 101. ID: gy10IL1XJ7TFVeqiLyAvPXhBdrPGiVSoCeaFqW4Eah8=, Name: MODE_gas_fees_over_90_day_window
# 102. ID: UUujjcsI0tpkUPH7/BqSve8dOCUgBlxmnkVpaQtfgYY=, Name: OPTIMISM_active_contracts_monthly
# 103. ID: j+fBdhkTjYsg+8o+kKpHuWR7h3rLs0H+wKH0daZ4poM=, Name: GITHUB_comments_monthly
# 104. ID: lvZ+SPAIF1LrcbtYjnFK7sRVafZkEJl7gfLcFU7G70o=, Name: MODE_active_addresses_rolling_over_90_day_window
# 105. ID: wEmengRABkjRy/uyUY1Sc7XEnDiPpU2SRtFtV6+TE6s=, Name: ARBITRUM_ONE_transactions_over_30_day_window
# 106. ID: f0N3z5i93rcayJzZETR/sFE5WkjPf4fxLGjNe2vmXO0=, Name: ZORA_active_addresses_rolling_over_30_day_window
# 107. ID: BHaP36iNQLsBm/akzX1nnkdQOk6zmW/XsPXQmeNa9zg=, Name: ARBITRUM_ONE_active_addresses_rolling_over_90_day_window
# 108. ID: IfxnwHFHqmsWqtEq4YwQXuxjRCHg5h/fWv2MDb/bU+8=, Name: MODE_active_contracts_over_all_time
# 109. ID: X8pAAXZH7dGbynvB+IQGRqJ9Izzrs4tWD5gg8NyDGF0=, Name: ARBITRUM_ONE_gas_fees_over_30_day_window
# 110. ID: A2/Al4/XWj5GyzTLbR10d9qgfZYmvQK42mKHefdI0Ts=, Name: GITHUB_full_time_contributors_over_90_day_window
# 111. ID: Nq5jSRImx81sqow9EfsLZEXPgNUm3j1IPKonOJbWfE4=, Name: ZORA_transactions_over_180_day_window
# 112. ID: S6msGMQZnKU3p4D3cPyOiDErD0rDhNjqE2NaxITg4S0=, Name: MODE_active_addresses_over_all_time
# 113. ID: 3YkLmQyyK68bfytf4PGjelRZkhd3ov4ulJX/c8otVu8=, Name: MODE_TRANSACTION_COUNT
# 114. ID: I62MZa+Gu2ljHju3GwngwZX3bGd9J2JCtxiglH5kIR8=, Name: GITHUB_full_time_contributors_over_30_day_window
# 115. ID: LRnntzEsR2KMcHoPFisxM0LoOeP6B98+orqvM0JXnuE=, Name: PGN_active_addresses_rolling_over_30_day_window
# 116. ID: SYyd7lCCq1oTFkrq/P4gzHtMTM6kjq4BstPY/Ns60dU=, Name: GITHUB_closed_issues_over_180_day_window
# 117. ID: HSrTUSQpLwXBubdbOG1UngTcpglaOTOst9Gdj3IFKJs=, Name: GITHUB_avg_prs_time_to_merge_over_90_day_window
# 118. ID: /a/4xjKmtf6IobbU1KXv5u5XPpPU8h1lLUB+QjtSWtI=, Name: ZORA_active_addresses_over_all_time
# 119. ID: 4qBeMINyZdzDjxrg3BGWFtXmyJrdGzvJt+m4U8XTr9w=, Name: GITHUB_change_in_part_time_developers_over_30_day_window_over_30_day_window
# 120. ID: V2ukmVepYgqXdOdiYxK0lqKghWNBZKUXSo3EvWG5oKs=, Name: METAL_active_contracts_weekly
# 121. ID: N4TgIn6CRPIfh+VB9s+9nhW5p8ccliFL8ytEDCEAKTY=, Name: METAL_active_contracts_monthly
# 122. ID: rW/sg3QZNCZSQDpf88ldx6KeA6g8WVeB+oKtcSvygMg=, Name: GITHUB_first_commit_over_all_time
# 123. ID: 7r6RCX0lXq6CctgL+sZ0xw6uDvTOimPX4DvXbpyMW6A=, Name: MODE_GAS_FEES
# 124. ID: KCiO84mySz4DsY9fr18jqXas3/5JEv6HtnpFiYnGY28=, Name: FRAX_GAS_FEES
# 125. ID: TDKHRHAfM33gXSZELP8m2GA4ZG1h+dpxSOjgdoU+2r0=, Name: BASE_gas_fees_over_180_day_window
# 126. ID: mSXbGlOoD2c1tUSDKJh/lel7ZCrMdiLbXR6NMiW8miY=, Name: GITHUB_change_in_part_time_developers_over_90_day_window_over_90_day_window
# 127. ID: gUHHFhr8igZ/j0o9+CqpdPfq+jqe/BtWJCR54gi95hQ=, Name: PGN_GAS_FEES
# 128. ID: PE/HlkQj+5mUPwKeOt3SDiJUA0aL6Ywp3mbvtckk5zM=, Name: OPTIMISM_active_addresses_aggregation_daily
# 129. ID: NkPcudP2RrL2nvZDTqPA+htICgT4eCVxcctvPUDfM8Q=, Name: OPTIMISM_gas_fees_over_90_day_window
# 130. ID: gF5rLaapiTaE/TZWb6yU+2VD0iMl4HFmPqoG0EpuVhI=, Name: GITHUB_active_developers_over_180_day_window
# 131. ID: 4/59H7SNhSFhvEY5SgJxmrSuX/cxSeafEQ2wi5lFROc=, Name: GITHUB_DEVELOPER_COUNT
# 132. ID: I3ytPjmx8TmQArvihClyuyGirinMM6ZjA0H9x6BgY84=, Name: GITHUB_full_time_developers_over_90_day_window
# 133. ID: G2aj792VVSZhk/oENCPGdapeVEozGum9W0o+Y0A5D9w=, Name: BASE_active_addresses_aggregation_daily
# 134. ID: FNLPOy6eHHckYViupbddIwyurEp7vqb+xpPY5X2Yya0=, Name: ARBITRUM_ONE_gas_fees_over_180_day_window
# 135. ID: yPZby2leyrspt9M3+tsJcOziBT/DbK5OobKEewQb+lg=, Name: GITHUB_change_in_full_time_developers_over_30_day_window_over_30_day_window
# 136. ID: 3PmYaM6TSzeSUaegJELWPREj341+9E5NDH/ycVVwE+g=, Name: METAL_active_addresses_aggregation_daily
# 137. ID: E+b1BnkUcO2MgD1yeAiGKrOrdATJUg57ld9NB7KGhdc=, Name: ARBITRUM_ONE_transactions_over_180_day_window
# 138. ID: gqPrgjDFJo0cxqAjtajifVr4f+ODszjovnISfmqT3qA=, Name: ZORA_active_addresses_aggregation_daily
# 139. ID: 9euZxf+JNl7Z4lEpFKt6OpkYvrmAJnOpy58RuxjSb9s=, Name: GITHUB_new_contributors_over_180_day_window
# 140. ID: DfOAe8+BEUgZmq1TWwclxekIvdIpa1VxoS9oJEj1+qM=, Name: GITHUB_releases_daily
# 141. ID: isF7dGYPanRTQHrlPswDHb7J0E9w1NwAn3siJSKko2w=, Name: OPTIMISM_gas_fees_over_180_day_window
# 142. ID: FdHzAcXbCc4mS7OLxMSZ5ynHn5QkWVxAzKyLtdk25LI=, Name: GITHUB_ISSUES_OPENED
# 143. ID: eV94RLJgcpOd+aMt8Y0sYGyN4V+6CCSwuxyZC7B1/FE=, Name: GITHUB_stars_daily
# 144. ID: FdT+qjxkLPDJgjLDgH0X9QR3lK+PQ658TBkLC7PKmJ0=, Name: GITHUB_merged_pull_requests_over_180_day_window
# 145. ID: BcOqAFWMH3FNe38q3vDSVquPLU0wzi0fVDdutj3+bZQ=, Name: MODE_active_addresses_aggregation_monthly
# 146. ID: 9k3LIKh6S//16hwsqVDr1BnnBbUQJJ8oJAxTvRiEoyE=, Name: ARBITRUM_ONE_GAS_FEES
# 147. ID: v5RFe5xNaFihpNLCCRotH8C9sTkIksp7XvUkdAaDh34=, Name: ARBITRUM_ONE_active_addresses_aggregation_daily
# 148. ID: mdOPLo22ZT1JNc0hem0AwAvi17t+BwVUY6/1N0kME7I=, Name: ARBITRUM_ONE_active_addresses_rolling_over_180_day_window
# 149. ID: g69yUgnojSiXyL1F+5a4GuQ8vSY7LTeTzj8+J+Y36tk=, Name: ARBITRUM_ONE_active_addresses_over_all_time
# 150. ID: xuMmxf6d6a7oY7/R4sa9JEUY4ktI42deYSZ7BR8WufA=, Name: GITHUB_full_time_developers_over_180_day_window
# 151. ID: jMfEW0jZLXCCgw8wZNa6IfZMwWG22vWs7iYRdjUN0AI=, Name: ZORA_gas_fees_over_180_day_window
# 152. ID: iHzAMzzmGelihmXKUgvp6yBVBtvMm2Vkvv9ZNqMfOuU=, Name: GITHUB_stars_weekly
# 153. ID: LbKt9vdmMuAezJvhFQw9qxJkodAXWbv8/L+KRvXGzCA=, Name: GITHUB_stars_monthly
# 154. ID: zqqzFEQxHTmLdyh9m6KMUUAdZL01Wt+C4SYmo1VPOn0=, Name: GITHUB_active_developers_over_all_time
# 155. ID: 0PLbykGaDSUa0WYCcoU7GdnYS97WVY6ct4Q91ZDOla0=, Name: OPTIMISM_active_addresses_rolling_over_30_day_window
# 156. ID: 7IEob03C+3q5ROGPuYG+MtIqqpb/GZ2l41Y1OSNbhDg=, Name: OPTIMISM_TRANSACTION_COUNT
# 157. ID: QiSmtZaITWn5Vo48HjJoL975jL2RHWnerK+ehtlzwso=, Name: PGN_transactions_over_180_day_window
# 158. ID: +78EY5c2yKhvzfEWuk6RNv8Sr5iWGTCBvUmMwXt8zFI=, Name: GITHUB_full_time_contributors_over_180_day_window
# 159. ID: gORTtmB+W99HTlxMUGKzZ+bknBDb7q0dVfgFMGEmDkc=, Name: METAL_gas_fees_over_30_day_window
# 160. ID: 3e8SGhJUe75eh3+1/+MVB4NyGk7+IVQ0oR+9cB2wYTE=, Name: BASE_transactions_over_90_day_window
# 161. ID: ccBpUgwcmV86G8Y2UXYt1MPv7R4HJvbG7QE5VaPR/Ds=, Name: PGN_transactions_over_30_day_window
# 162. ID: uI/7YwS/Onu2MWbVrYmL7Nl2XtZBBMbLaSyIpsoabI0=, Name: PGN_active_addresses_aggregation_monthly
# 163. ID: JY2E0UUwab0lB00HcUMMO3OljZBXNuKBQUmY7RxeOB4=, Name: ARBITRUM_ONE_active_contracts_weekly
# 164. ID: YYdvcoB4s2QY3J6aQD7FOAuexdATSk+5KL7AwHE1KgE=, Name: FRAX_active_contracts_over_all_time
# 165. ID: q5s5EZJLtv9hMo9EYBzV23JmuCnK/5MqIOn7fnVpYvQ=, Name: BASE_active_addresses_aggregation_monthly
# 166. ID: OcQ1JtGmkJjKwU0S1VBleeKq+Gl2Cbio/rPDM2nhqFU=, Name: FRAX_active_contracts_monthly
# 167. ID: VrLBlXqy8orX8k4O66Ls4trTBCdD1dnG7oCz5jal0Mw=, Name: GITHUB_opened_pull_requests_over_180_day_window
# 168. ID: 8UbMdJeXuYWNUL9frmEf27gXxoyr23/Vacgt9KH7T/0=, Name: MODE_active_addresses_rolling_over_30_day_window
# 169. ID: JY/1aKSI5lLL3czI27HV5ugNIYt67mVsPQa8tj8q8/o=, Name: BASE_gas_fees_over_30_day_window
# 170. ID: 3E8NgIxXz0P40UJQlS4lyoWdbN9B2E+fwJzJqE1SSTE=, Name: OPEN_COLLECTIVE_FUNDING_RECEIVED
# 171. ID: C1X5K+Q+J36CxAhWGgwL/XX2BIjfu2ADA25uFtF8cHQ=, Name: METAL_transactions_over_30_day_window
# 172. ID: gm6EfzIkQw+SpsY+E8Y4cx0rxdYZ5/+OQjjwPxLL17E=, Name: ZORA_active_addresses_aggregation_monthly
# 173. ID: eOwclnUw5yKDVYxxptGLq+no6533fouFULzG6o4IDHA=, Name: GITHUB_releases_monthly
# 174. ID: Nj41sXr1SVd3SpXWVxbHSjvFg+65I98D5BNfiiA+6Uw=, Name: GITHUB_forks_weekly
# 175. ID: fedqW3D5QjVidgzZsVSya82sTqGx/RKZbtSN27xL6es=, Name: GITHUB_repositories_daily
# 176. ID: zwsgu/qp8gOubkW3nwyqDVqHXj4Q2Ll0NegybuN+nic=, Name: METAL_gas_fees_over_90_day_window
# 177. ID: NmlrFAAozUWy0gD922EVkSpcJtMN7SdtYsCFWQgC9NY=, Name: FRAX_active_addresses_rolling_over_30_day_window
# 178. ID: F4KGkCAnZvWwoPPF4GrI88h0kxtTdy8B2VYY9tospq0=, Name: PGN_active_addresses_aggregation_daily
# 179. ID: q/sTO8R0D1zRAifZ8T1CdRSRFC+rL8kzQVDQ/nhzAQk=, Name: MODE_gas_fees_over_30_day_window
# 180. ID: oy1g3nvQdXnXM1LCflAO0xVef3ucpAfTmdbDIcUr4C8=, Name: METAL_GAS_FEES
# 181. ID: huRdAh+307pN4AfhIW1GCmz038DoO1c9HpQT9PZ8oto=, Name: METAL_active_addresses_rolling_over_90_day_window
# 182. ID: oJhCm3QCBfUXPogOVoiQcOP5CpAI577TQNMFzN78HxA=, Name: GITHUB_CONTRIBUTOR_ACTIVE_DAYS
# 183. ID: 284o6CUVUShIJ3Ad+ffPTCuTJY9z0xURCAPaAHU8+p4=, Name: BASE_active_addresses_over_all_time
# 184. ID: PX009YsfS/l9oEXfIcJNAZQ4foTVrgnGvBNbrLpo3uo=, Name: METAL_active_contracts_daily
# 185. ID: 4RMwikzLmSG2bwtW+MEFGwIVk7/IjFftTPZ9rU3Isr4=, Name: GITHUB_contributors_daily
# 186. ID: LCFouzQwjjfdxUPADhwuhdo7WKOtPzDkGdi+2P1KI3Y=, Name: GITHUB_PRS_MERGED
# 187. ID: LqKbNXhlIL/Kq0BxvYyui4WOuSqQirV4BPfQh9rvjoE=, Name: ZORA_transactions_over_30_day_window
# 188. ID: AcBjj9F0vFsqdm2CJT41NykLocfwC+CJtDjL4MFn9U0=, Name: OPTIMISM_active_addresses_over_all_time
# 189. ID: ITJQTRPsaz43crlwYkklRjMfcBELL+9HKg93b5VrhQI=, Name: METAL_active_addresses_over_all_time
# 190. ID: 4Li6Ni7ep3kClir+yptEV4cHgeXXb3jqEC+FGttWXl0=, Name: ZORA_active_addresses_rolling_over_90_day_window
# 191. ID: Zd5SDH+yvFJlmk4v1stWamVDWJhQgoeIgkGmTgq7FaM=, Name: FRAX_gas_fees_over_30_day_window
# 192. ID: 8oVBt/WidET++OTvxowXmzJRSYVgXHhRQPB0R/JXIa0=, Name: GITHUB_forks_daily
# 193. ID: 5jnblBDVEsescKE6RNK4ybjswEk+mtwXykgcxm1bQHc=, Name: GITHUB_opened_issues_over_180_day_window
# 194. ID: EFCGFZCFIh282+wmZcen4UXCucw5zEB0cc5M7S8UnGM=, Name: BASE_gas_fees_over_90_day_window
# 195. ID: 1/VJhKpvRaFL6yRkiJF/smvvZBjXvHOofTEOcFi8Bts=, Name: BASE_active_addresses_rolling_over_180_day_window
# 196. ID: u/lXeIf7d7aZE2QK00lqDY1gbHmP1M3e3IGilCLKgqY=, Name: MODE_active_contracts_weekly
# 197. ID: YpnMhxBtVxJBnvpZumbg/rtPHjs7WYdFkO6HYC+kD9M=, Name: GITHUB_active_contributors_over_90_day_window
# 198. ID: ip1fo4ghWhtqnVqlB+c6fIdyiP6VzCZh5F2/mTZAJME=, Name: GITHUB_comments_weekly
# 199. ID: xdxWbfeAuQawUUnx7SM+WWycBoMrfQtNcSAa6OcKtRI=, Name: FRAX_active_addresses_aggregation_daily

# %%
# Step 3: Fetch Time Series Data for a specific project-metric pair
project_index=83
metric_index=185
if projects and metrics:
    project_id = projects[project_index]["projectId"]  # Pick first project
    metric_id = metrics[metric_index]["metricId"]  # Pick first metric

    metric_name = metrics[metric_index]["metricName"]
    project_name = projects[project_index]["projectName"] 


    print(f"Metric Name: ", metric_name)
    print(f"Project Name: ", project_name)

    QUERY_TIME_SERIES = f"""
    query {{
        oso_timeseriesMetricsByProjectV0(
        where: {{projectId: {{_eq: "{project_id}"}}, metricId: {{_eq: "{metric_id}"}}}}
        order_by: {{sampleDate: Asc}}
        limit: 90
        ) {{
        sampleDate
        amount
        }}
    }}
    """

    time_series_data = fetch_data(QUERY_TIME_SERIES)
    print("\nTime Series Data:")
    if time_series_data:
        for record in time_series_data["data"]["oso_timeseriesMetricsByProjectV0"]:
            print(f"Date: {record['sampleDate']}, Amount: {record['amount']}")
# Out:
# Metric Name:  GITHUB_contributors_daily
# Project Name:  renzo-protocol
#
# Time Series Data:
# Date: 2023-12-11, Amount: 1
# Date: 2023-12-13, Amount: 1
# Date: 2024-01-10, Amount: 1
# Date: 2024-01-30, Amount: 1
# Date: 2024-02-02, Amount: 1
# Date: 2024-02-06, Amount: 1
# Date: 2024-03-13, Amount: 1
# Date: 2024-04-03, Amount: 1
# Date: 2024-04-07, Amount: 1
# Date: 2024-04-22, Amount: 1
# Date: 2024-04-25, Amount: 1
# Date: 2024-04-27, Amount: 1
# Date: 2024-04-30, Amount: 1
# Date: 2024-05-11, Amount: 1
# Date: 2024-06-12, Amount: 2
# Date: 2024-07-09, Amount: 2
# Date: 2024-07-22, Amount: 1
# Date: 2024-07-24, Amount: 2
# Date: 2024-07-30, Amount: 1
# Date: 2024-08-15, Amount: 1
# Date: 2024-08-19, Amount: 1
# Date: 2024-08-23, Amount: 1
# Date: 2024-08-26, Amount: 1
# Date: 2024-08-29, Amount: 1
# Date: 2024-09-05, Amount: 1
# Date: 2024-09-07, Amount: 1
# Date: 2024-09-18, Amount: 1
# Date: 2024-09-19, Amount: 1
# Date: 2024-09-26, Amount: 1
# Date: 2024-09-29, Amount: 1
# Date: 2024-10-14, Amount: 1
# Date: 2024-10-15, Amount: 1
# Date: 2024-12-28, Amount: 1
